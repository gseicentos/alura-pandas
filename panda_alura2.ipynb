# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
dados = pd.read_csv(url, sep=';')
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
dados['Valor_por_mes']= dados['Valor'] + dados['Condominio']
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes
# 0  1700.0       500.0    60.0         2200.0
# 1  7000.0         NaN     NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0
# 3   800.0       390.0    20.0         1190.0
# 4   800.0       230.0     NaN         1030.0

# %%
dados.fillna(0, inplace=True)
dados['Valor_por_mes']= dados['Valor'] + dados['Condominio']
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU  Valor_por_mes
# 0   1700.0       500.0    60.0         2200.0
# 1   7000.0         0.0     0.0         7000.0
# 2   5200.0      4020.0  1111.0         9220.0
# 3    800.0       390.0    20.0         1190.0
# 4    800.0       230.0     0.0         1030.0
# 5   1200.0         0.0     0.0         1200.0
# 6   1300.0       301.0    17.0         1601.0
# 7  22000.0         0.0     0.0        22000.0
# 8   1000.0         0.0     0.0         1000.0
# 9  35000.0     19193.0  3030.0        54193.0

# %%
dados['Valor_por_ano'] = dados['Valor_por_mes'] * 12 + dados['IPTU']
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano
# 0   1700.0       500.0    60.0         2200.0        26460.0
# 1   7000.0         0.0     0.0         7000.0        84000.0
# 2   5200.0      4020.0  1111.0         9220.0       111751.0
# 3    800.0       390.0    20.0         1190.0        14300.0
# 4    800.0       230.0     0.0         1030.0        12360.0
# 5   1200.0         0.0     0.0         1200.0        14400.0
# 6   1300.0       301.0    17.0         1601.0        19229.0
# 7  22000.0         0.0     0.0        22000.0       264000.0
# 8   1000.0         0.0     0.0         1000.0        12000.0
# 9  35000.0     19193.0  3030.0        54193.0       653346.0

# %%
dados['Descricao'] = dados['Tipo'] + ' em ' + dados['Bairro'] + ' com ' + dados['Quartos'].astype(str) + ' quarto(s) ' + ' e ' + dados['Vagas'].astype(str  ) + ' vaga(s) '
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano  \
# 0   1700.0       500.0    60.0         2200.0        26460.0
# 1   7000.0         0.0     0.0         7000.0        84000.0
# 2   5200.0      4020.0  1111.0         9220.0       111751.0
# 3    800.0       390.0    20.0         1190.0        14300.0
# 4    800.0       230.0     0.0         1030.0        12360.0
# 5   1200.0         0.0     0.0         1200.0        14400.0
# 6   1300.0       301.0    17.0         1601.0        19229.0
# 7  22000.0         0.0     0.0        22000.0       264000.0
# 8   1000.0         0.0     0.0         1000.0        12000.0
# 9  35000.0     19193.0  3030.0        54193.0       653346.0
#
#                                            Descricao
# 0  Quitinete em Copacabana com 1 quarto(s)  e 0 v...
# 1  Casa em Jardim Botânico com 2 quarto(s)  e 0 v...
# 2  Conjunto Comercial/Sala em Barra da Tijuca com...
# 3  Apartamento em Centro com 1 quarto(s)  e 0 vag...
# 4  Apartamento em Higienópolis com 1 quarto(s)  e...
# 5  Apartamento em Vista Alegre com 3 quarto(s)  e...
# 6  Apartamento em Cachambi com 2 quarto(s)  e 0 v...
# 7  Casa de Condomínio em Barra da Tijuca com 5 qu...
# 8  Casa de Condomínio em Ramos com 2 quarto(s)  e...
# 9  Conjunto Comercial/Sala em Centro com 0 quarto...

# %%
dados['Possui_suite'] = dados['Suites'].apply(lambda x: "Sim" if x>0 else "Não")
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano  \
# 0   1700.0       500.0    60.0         2200.0        26460.0
# 1   7000.0         0.0     0.0         7000.0        84000.0
# 2   5200.0      4020.0  1111.0         9220.0       111751.0
# 3    800.0       390.0    20.0         1190.0        14300.0
# 4    800.0       230.0     0.0         1030.0        12360.0
# 5   1200.0         0.0     0.0         1200.0        14400.0
# 6   1300.0       301.0    17.0         1601.0        19229.0
# 7  22000.0         0.0     0.0        22000.0       264000.0
# 8   1000.0         0.0     0.0         1000.0        12000.0
# 9  35000.0     19193.0  3030.0        54193.0       653346.0
#
#                                            Descricao Possui_suite
# 0  Quitinete em Copacabana com 1 quarto(s)  e 0 v...          Não
# 1  Casa em Jardim Botânico com 2 quarto(s)  e 0 v...          Sim
# 2  Conjunto Comercial/Sala em Barra da Tijuca com...          Não
# 3  Apartamento em Centro com 1 quarto(s)  e 0 vag...          Não
# 4  Apartamento em Higienópolis com 1 quarto(s)  e...          Não
# 5  Apartamento em Vista Alegre com 3 quarto(s)  e...          Não
# 6  Apartamento em Cachambi com 2 quarto(s)  e 0 v...          Não
# 7  Casa de Condomínio em Barra da Tijuca com 5 qu...          Sim
# 8  Casa de Condomínio em Ramos com 2 quarto(s)  e...          Não
# 9  Conjunto Comercial/Sala em Centro com 0 quarto...          Não

# %%
dados.to_csv('dados_completo_dev.csv', index=False, sep=';')
